# %%
# Load in sim data
import hax

# using modified version of Tianyu's OtherLargeS2s peak extractor
from make_minitree import Peaks

hax.init(experiment='XENON1T',
         use_runs_db=False,
         pax_version_policy='loose',
         main_data_paths=['~/data/nr_ss_sim/testing_fax'],
         minitree_paths = ['~/data/nr_ss_sim/testing_fax'])
# Out:
# INFO:hax.__init__] Not looking for datasets in runs, db since you put use_runs_db = False
# WARNING:hax.__init__] You're not at a XENON analysis facility, or hax can't detect at which analysis facility you are.

# %%
sim = hax.minitrees.load("testing_fax",["Basics"])
# Out:
# WARNING:hax.runs] Blinding by default since cannot find run.
# DEBUG:hax.minitrees] Minitree testing_fax_Basics.root not found
# DEBUG:hax.minitrees] Not found in non-preferred formats either. Minitree will be created.
# Could not find run number for testing_fax, got exception <class 'AttributeError'>: 'NoneType' object has no attribute 'query'. Setting run number to 0.
# Don't know a run named testing_fax, trying to find it anyway...
# Run testing_fax: Making Basics minitree: 100%|██████████| 7/7 [00:00<00:00, 105.58it/s]
# DEBUG:hax.__init__] Extraction completed, now concatenating data
# DEBUG:hax.minitrees] Retrieved Basics minitree data for dataset testing_fax
# Don't know a run named testing_fax, trying to find it anyway...
# DEBUG:hax.minitrees] Found minitree at /home/shawaf/data/nr_ss_sim/testing_fax/testing_fax_Basics.root
# DEBUG:hax.minitrees] Removing weird index column
# ...

# %%
sim
# Out:
#          cs1          cs2  drift_time  event_number  largest_coincidence  \
# 0   9.430343  5115.619644    444610.0             0                    0
# 1   4.205202  3697.605456    378230.0             1                    0
# 2        NaN          NaN         NaN             2                    0
# 3   3.642311  4169.204101    524280.0             3                    0
# 4  30.323112  8393.334172    218530.0             4                    0
# 5  32.065232  8681.256404    297060.0             5                    0
# 6  38.929682  8155.985482    355980.0             6                    0
#
#    largest_other_s1  largest_other_s2  largest_unknown  largest_veto  \
# 0                 0         52.247265                0             0
# 1                 0         39.785908                0             0
# 2                 0        293.395691                0             0
# 3                 0         31.547260                0             0
# ...

# %%
import pandas as pd
instruct = pd.read_csv('~/data/nr_ss_sim/testing_fax/test.csv')

# %%
instruct
# Out:
#    instruction recoil_type          x          y      depth  s1_photons  \
# 0         2372          NR  37.508572 -10.944522  63.698288          89
# 1         5661          NR  40.526188  -6.876606  54.050465          50
# 2         5953          NR  18.128426  23.639423  52.673916           9
# 3         6422          NR  37.953838  11.485145  75.183723          22
# 4         8282          NR  24.446436  24.383989  31.134218         272
# 5         9093          NR  25.659214  22.702929  42.450420         263
# 6        14656          NR  41.410908   1.621158  51.012199         344
#
#    s2_electrons       t
# 0           184  500000
# 1           134  500000
# 2            26  500000
# 3           141  500000
# 4           337  500000
# 5           292  500000
# 6           323  500000
